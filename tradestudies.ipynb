# %%
# Cruise Altitude
cruise_alt = [30000, 31000, 32000, 33000, 34000, 35000, 36000, 37000, 38000, 39000, 40000]

takeoff_weight_m0_78 = [1310929.15, 1308610.79, 1306748.04, 1305359.2, 1304456.56, 1304061.5, 1304189.78, 1304943.0, 1306540.2, 1309005.31, 1312356.7]

takeoff_weight_m0_8 = [1309189.67, 1306376.35, 1304001.79, 1302082.88, 1300630.78, 1299662.63, 1299197.94, 1299174.59, 1299951.57, 1301559.57, 1304014.38]

takeoff_weight_m0_82 = [1306962.87, 1303478.87, 1300421.11, 1297800.42, 1295632.07, 1293927.34, 1292704.61, 1291761.28, 1291573.4, 1292188.75, 1293618.14]

import matplotlib.pyplot as plt
plt.plot(cruise_alt, takeoff_weight_m0_78, label='M = 0.78')
plt.plot(cruise_alt, takeoff_weight_m0_8, label='M = 0.80')
plt.plot(cruise_alt, takeoff_weight_m0_82, label='M = 0.82')
plt.xlabel("Cruise Altitude (ft)")
plt.ylabel("Takeoff Weight (lbs)")
plt.legend()
plt.show()
